# %% [markdown]
# #Second Episode of MCI AI and Machine Learning For Begineer - Topic: Classification 2 --Le Duc Anh

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Confuse Matrix--more specific

# %% [markdown]
# #K-nearest Neighbors

# %% [markdown]
# #Kernel SCM

# %% [markdown]
# #Decision tree Classification

# %% [markdown]
# #Ensemble Trees

# %% [markdown]
# #Classification Model Selection

# %% [markdown]
# #Models Performance Evaluation Endeavor
